# %%
import pandas as pd
df = pd.read_csv('../data/raw/raw_data.csv')
print(df.shape)
print(df.head())
print(df['Qualite'].value_counts())
print(df['Qualite'].value_counts(normalize=True) * 100)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       2 df = pd.read_csv('../data/raw/raw_data.csv')
#       3 print(df.shape)
#       4 print(df.head())
#
# ModuleNotFoundError: No module named 'pandas'
